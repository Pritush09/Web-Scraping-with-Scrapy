# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_json("C:/Users/mynam/DataScience MLDL/Projects/Web Scraping using scrapy/bookscraper/cleandata.json")

# %%
df.head()
# Out:
#                                                  url  \
# 0  http://books.toscrape.com/catalogue/scott-pilg...
# 1  http://books.toscrape.com/catalogue/our-band-c...
# 2  http://books.toscrape.com/catalogue/libertaria...
# 3  http://books.toscrape.com/catalogue/mesaerion-...
# 4  http://books.toscrape.com/catalogue/rip-it-up-...
#
#                                                title               upc  \
# 0  Scott Pilgrim's Precious Little Life (Scott Pi...  3b1c02bac2a429e6
# 1  Our Band Could Be Your Life: Scenes from the A...  deda3e61b9514b83
# 2                       Libertarianism for Beginners  a18a4f574854aced
# 3  Mesaerion: The Best Science Fiction Stories 18...  e30f54cea9b38190
# 4                          Rip it Up and Start Again  a34ba96d4081e6a4
#
#   product_type  price_excl_tax  price_incl_tax  tax  availability  \
# 0        books           52.29           52.29    0            19
# 1        books           57.25           57.25    0            19
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   url             1000 non-null   object
#  1   title           1000 non-null   object
#  2   upc             1000 non-null   object
#  3   product_type    1000 non-null   object
#  4   price_excl_tax  1000 non-null   float64
#  5   price_incl_tax  1000 non-null   float64
#  6   tax             1000 non-null   int64
#  7   availability    1000 non-null   int64
#  8   num_reviews     1000 non-null   int64
#  9   stars           1000 non-null   int64
#  10  category        1000 non-null   object
#  11  description     998 non-null    object
#  12  price           1000 non-null   float64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 101.7+ KB
